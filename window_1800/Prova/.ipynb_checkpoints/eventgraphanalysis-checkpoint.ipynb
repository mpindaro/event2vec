# %%
import pandas as pd

# %%
events_types = {"1A": {"start": "X", "end":"Z" },\
                "1B": {"start": "X", "end":"Z" },\
                "2": {"start": "A", "end":"Y" },\
                "3A": {"start": "X", "end":"Z" },\
                "3B": {"start": "X", "end":"Z" },\
                "4A": {"start": "A", "end":"Y" },\
                "4B": {"start": "A", "end":"Y" }}

# %%
events = pd.read_csv("../data/events.csv")

# %%
events = events[ events["significativo"]<0.05]

# %%
events.reset_index(inplace=True, drop = True)
events
# Out:
#              A        B      X      Y       Z  chiamate evento   p0  \
# 0          NaN      NaN   1773   1766  1849.0         4     1A  0.0
# 1          NaN      NaN   1765   1766  1767.0         4     1A  0.0
# 2          NaN      NaN   1765   1766  1767.0         4     1A  0.0
# 3          NaN      NaN   2102   2050  2099.0         2     1A  0.0
# 4          NaN      NaN   2071  34458  2058.0        16     1A  0.0
# ...        ...      ...    ...    ...     ...       ...    ...  ...
# 12210  45991.0  45992.0  33400  33400     NaN         6     4B  0.0
# 12211  45995.0  46551.0  33400  33400     NaN         3     4B  0.0
# 12212  45995.0  46551.0  33400  33400     NaN         3     4B  0.0
# 12213  45995.0  46551.0  33400  33400     NaN         3     4B  0.0
# 12214  45995.0  46551.0  33400  33400     NaN         3     4B  0.0
#
#        p_cappuccio  significativo   timestamp    z
# 0         0.000059            0.0  1470574374  inf
# ...

# %%
for i, row in events.iterrows():
